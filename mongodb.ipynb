# %%
import pymongo
from pymongo import MongoClient

# %%
connection_string = "mongodb+srv://shivangkonde99_db_user:ssk1234@cluster0.or8rtpz.mongodb.net/?appName=Cluster0"

# %%
client =MongoClient(connection_string)

# %%
db= client["liveClass"]   #liveclass is db name

# %%
collection=db["mongoclss"]  #mongoclass is collection name

# %%
data={"name":"shiva",
      "age":25,
      "email":"shiva24@gmail.com"}

# %%
collection.insert_one(data)

# %%
op=collection.find({})
print(op)

# %%
for i in op:
    print(i)
# Out:
# {'_id': ObjectId('6922ba62da000e31e0ffbbfe'), 'name': 'shiva', 'age': 25, 'email': 'shiva24@gmail.com'}
